# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswinee0802/learner/blob/main/image_processing_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://wallup.net/wp-content/uploads/2018/10/06/364495-dog-puppy-dogs-baby.jpg
# Out:
# --2024-04-02 19:28:55--  https://wallup.net/wp-content/uploads/2018/10/06/364495-dog-puppy-dogs-baby.jpg
# Resolving wallup.net (wallup.net)... 144.76.39.8
# Connecting to wallup.net (wallup.net)|144.76.39.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 406682 (397K) [image/jpeg]
# Saving to: ‘364495-dog-puppy-dogs-baby.jpg’
#
# 364495-dog-puppy-do 100%[===================>] 397.15K  1.10MB/s    in 0.4s
#
# 2024-04-02 19:28:56 (1.10 MB/s) - ‘364495-dog-puppy-dogs-baby.jpg’ saved [406682/406682]

# %% [markdown]
# 1. matplotlib image
# 2. pillow
# 3. OpenCV

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/364495-dog-puppy-dogs-baby.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1618, 2045, 3)

# %%
print(img)
# Out:
# [[[106  93  59]
#   [105  92  58]
#   [112  99  65]
#   ...
#   [124 120  82]
#   [125 121  83]
#   [119 117  79]]
#
#  [[107  94  60]
#   [106  93  59]
#   [113 100  66]
#   ...
#   [124 120  82]
#   [126 122  84]
#   [119 117  79]]
#
#  [[112  99  65]
#   [111  98  64]
#   [117 104  70]
#   ...
#   [124 120  82]
#   [126 122  84]
#   [120 118  80]]
#
#  ...
#
#  [[ 78  67  37]
#   [ 64  53  23]
#   [ 49  38  10]
#   ...
#   [  9   9   0]
#   [ 19  20  12]
#   [ 12  13   5]]
#
#  [[109  96  64]
#   [ 93  80  48]
#   [ 69  58  28]
#   ...
#   [ 15  15   5]
#   [ 12  12   4]
#   [  9  10   4]]
#
#  [[117 104  70]
#   [102  89  55]
#   [ 79  68  38]
#   ...
#   [ 12  12   4]
#   [ 10  10   2]
#   [  6   7   2]]]

# %%
#displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# resizing the image using pilow library

# %%
from PIL import Image

# %%
img = Image.open('/content/364495-dog-puppy-dogs-baby.jpg')
img_resized = img.resize((100,100))

# %%
print(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F72883896C0>

# %%
img_resized.save('/content/364495-dog-puppy-dogs-baby_resized.jpg')

# %%
img_res = mpimg.imread('/content/364495-dog-puppy-dogs-baby.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (1618, 2045, 3)

# %% [markdown]
# **converting RGB images to GRayscale image using Opencv**

# %%
# importing Opencv library
import cv2

# %%
img = cv2.imread('/content/364495-dog-puppy-dogs-baby.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1618, 2045)

# %% [markdown]
# **cv2.imshow()** will display the image but this will not work in google collab

# %%
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=2045x1618>

# %%
#saving the grayscale image
cv2.imwrite('/content/364495-dog-puppy-dogs-baby.jpg', grayscale_image)
# Out:
# True
